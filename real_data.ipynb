# %%
import os
import h5py
import glob
import matplotlib.pyplot as plt
from gwosc.timeline import get_segments
from gwpy.timeseries import TimeSeries
from lalframe.utils import frtools

# %% [markdown]
# ### Fetch Open Data

# %%
ifo = "L1"
sample_rate = 4096
format = "gwf"
O3b_start = 1256655618
O3b_end = 1269363618

# Searching for the available segments
L1_segments = get_segments(
    f"{ifo}_DATA",
    start=O3b_start,
    end=O3b_end,
)
seg_id = 0
chosen_seg = L1_segments[seg_id]
print(f"Chosen segment: {chosen_seg}")
print(f"Length of segment {seg_id}: {chosen_seg[1] - chosen_seg[0]}")

# Create folders
working_dir = "/home/jerry/GW/glitch-classification/Omicron"
data_dir = f"/home/jerry/GW/glitch-classification/Data"
output_dir = f"{working_dir}/triggers"
if not os.path.exists(working_dir):
    os.mkdir(working_dir)
if not os.path.exists(data_dir):
    os.mkdir(data_dir)
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
# Out:
# Chosen segment: (1256655666, 1256657739)
# Length of segment 0: 2073

# %%
# Fetch time series data
print(f"Fetching {ifo} Data: {chosen_seg[0]} s to {chosen_seg[1]} s.")
ts = TimeSeries.fetch_open_data(
    ifo=ifo,
    start=chosen_seg[0],
    end=chosen_seg[1],
    sample_rate=sample_rate,
    format=format,
)

# Save time series data for Omicron analysis
gwf_file = f"{data_dir}/{ifo[0]}-{ifo}_GWOSC_DATA-{chosen_seg[0]}-{chosen_seg[1]-chosen_seg[0]}.gwf"
ts.write(gwf_file, format=format)
print(f"Data written to {gwf_file}.")
# Out:
# Fetching L1 Data: 1256655666 s to 1256657739 s.
# Data written to /home/jerry/GW/glitch-classification/Data/L-L1_GWOSC_DATA-1256655666-2073.gwf.

# %% [markdown]
# ### Run Omicron

# %%
start = chosen_seg[0]
end = chosen_seg[1]
# Get channel name from the downloaded data
gwf_file = f"{data_dir}/{ifo[0]}-{ifo}_GWOSC_DATA-{chosen_seg[0]}-{chosen_seg[1]-chosen_seg[0]}.gwf"
channel = frtools.get_channels(gwf_file)[0]
print(f"Channel name: {channel}")
# Out:
# Channel name: L1:GWOSC-4KHZ_R1_STRAIN

# %%
# Generating lcf file
os.chdir(working_dir)
lcf_content = f"{ifo} {channel} {start} {end-start} {gwf_file}"
lcf_file = f"{working_dir}/frames.lcf"
with open(lcf_file, 'w') as file:
    file.write(lcf_content)

# Generating parameters.txt
parameter_content = f"""\
# Omicron parameter file

PARAMETER CLUSTERING       TIME
PARAMETER FFTPLAN          FFTW_ESTIMATE
PARAMETER TRIGGERRATEMAX   100000
PARAMETER QRANGE           3.3166 108.0
PARAMETER FREQUENCYRANGE   32.0 2048.0
PARAMETER CLUSTERDT        0.5
PARAMETER MISMATCHMAX      0.2
PARAMETER SNRTHRESHOLD     5.0 
PARAMETER PSDLENGTH        124
PARAMETER TIMING           64 4

OUTPUT    DIRECTORY        {output_dir}
OUTPUT    PRODUCTS         triggers
OUTPUT    VERBOSITY        1
OUTPUT    FORMAT           hdf5
OUTPUT    NTRIGGERMAX      10000000.0

DATA      SAMPLEFREQUENCY  1024
DATA      FFL              {lcf_file}
DATA      CHANNELS         {channel}
"""
parameter_file = f"{working_dir}/parameters.txt"
with open(parameter_file, 'w') as file:
    file.write(parameter_content)

# %%
# Run Omicron
os.chdir(working_dir)
os.system(f"omicron {start} {end} {parameter_file} strict")
# Out:
# C system headers (glibc/Xcode/Windows SDK) must be installed.
# In file included from input_line_4:36:
# /home/jerry/miniforge3/envs/glitch-classification/bin/../lib/gcc/x86_64-conda-linux-gnu/13.3.0/include/c++/cassert:44:10: fatal error: 'assert.h' file not found
# #include <assert.h>
#          ^~~~~~~~~~
# ##############################################################
# ##############################################################
#
#    ██████╗ ███╗   ███╗██╗ ██████╗██████╗  ██████╗ ███╗   ██╗
#   ██╔═══██╗████╗ ████║██║██╔════╝██╔══██╗██╔═══██╗████╗  ██║
#   ██║   ██║██╔████╔██║██║██║     ██████╔╝██║   ██║██╔██╗ ██║
#   ██║   ██║██║╚██╔╝██║██║██║     ██╔══██╗██║   ██║██║╚██╗██║
#   ╚██████╔╝██║ ╚═╝ ██║██║╚██████╗██║  ██║╚██████╔╝██║ ╚████║
#    ╚═════╝ ╚═╝     ╚═╝╚═╝ ╚═══��═╝╚═╝  ╚═╝ ╚═════╝ ╚═╝  ╚═══╝
#                                                     4.1.1
# ##############################################################
# ##############################################################
#
#
# IO::ParseFile: Parse file /home/jerry/GW/glitch-classification/Omicron/parameters.txt		ok
# Omicron::ReadOptions: number of options = 43
# ffl::ffl: detect file format
# ffl::Convert2Ffl: FFL conversion
# ffl::Reset: reset ffl
# ffl::LoadFrameFile: load FFL file
# ffl::LoadFrameFile: extract frame information
# ffl::LoadFrameFile: check frame information
# Streams::MakeDetector: this stream (L1:GWOSC-4KHZ_R1_STRAIN) is associated to detector: Livingston (L1)
# Sample::SetFrequencies: new native sampling frequency (4096Hz)
# Sample::SetFrequencies: new working sampling frequency (1024Hz)
# Otile::Otile: creating 5 Q-planes
# InjRea::InjRea: 0 injections are loaded
#
# >>>>>>>>>> (06:45:47 UTC) [+0s]: Omicron has been successfully initiated <<<<<<<<<<
#
# Omicron::InitSegments: initiate data segments...
# Osequence::SetSegments: setting new segments
# Omicron::MakeDirectories: make directory structure...
#
# >>>>>>>>>> (06:45:48 UTC) [+1s]: Start looping over channels and chunks <<<<<<<<<<
#
# Omicron::NewChannel: load a new channel...
# 	- channel L1:GWOSC-4KHZ_R1_STRAIN (1/1) is loaded
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256655666-1256655730
# 	- chunk 1256655666-1256655730 is loaded (start a new segment)
#
# >>>>>>>>>> (06:45:48 UTC) [+1s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256655666-1256655730 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::ComputeMedianMean: the PSD estimation is not nominal: 30/29 subPSDs are used instead of 62/61
# Spectrum::AddData: compute PSD
# Spectrum::ComputeMedianMean: the PSD estimation is not nominal: 30/29 subPSDs are used instead of 62/61
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256655668.00000-1256655728.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 764 triggers...
# Triggers::Clusterize: 4 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256655726-1256655790
# 	- chunk 1256655726-1256655790 is loaded
#
# >>>>>>>>>> (06:45:48 UTC) [+1s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256655726-1256655790 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::ComputeMedianMean: the PSD estimation is not nominal: 60/58 subPSDs are used instead of 62/61
# Spectrum::AddData: compute PSD
# Spectrum::ComputeMedianMean: the PSD estimation is not nominal: 60/58 subPSDs are used instead of 62/61
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256655728.00000-1256655788.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 111 triggers...
# Triggers::Clusterize: 3 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256655786-1256655850
# 	- chunk 1256655786-1256655850 is loaded
#
# >>>>>>>>>> (06:45:49 UTC) [+2s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256655786-1256655850 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256655788.00000-1256655848.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 59 triggers...
# Triggers::Clusterize: 1 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256655846-1256655910
# 	- chunk 1256655846-1256655910 is loaded
#
# >>>>>>>>>> (06:45:49 UTC) [+2s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256655846-1256655910 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256655848.00000-1256655908.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 29 triggers...
# Triggers::Clusterize: 2 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256655906-1256655970
# 	- chunk 1256655906-1256655970 is loaded
#
# >>>>>>>>>> (06:45:49 UTC) [+2s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256655906-1256655970 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256655908.00000-1256655968.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 0 triggers...
# Triggers::Clusterize: 0 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256655966-1256656030
# 	- chunk 1256655966-1256656030 is loaded
#
# >>>>>>>>>> (06:45:50 UTC) [+3s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256655966-1256656030 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256655968.00000-1256656028.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 2159 triggers...
# Triggers::Clusterize: 5 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656026-1256656090
# 	- chunk 1256656026-1256656090 is loaded
#
# >>>>>>>>>> (06:45:50 UTC) [+3s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656026-1256656090 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656028.00000-1256656088.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 7 triggers...
# Triggers::Clusterize: 4 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656086-1256656150
# 	- chunk 1256656086-1256656150 is loaded
#
# >>>>>>>>>> (06:45:51 UTC) [+4s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656086-1256656150 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656088.00000-1256656148.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 4714 triggers...
# Triggers::Clusterize: 4 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656146-1256656210
# 	- chunk 1256656146-1256656210 is loaded
#
# >>>>>>>>>> (06:45:51 UTC) [+4s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656146-1256656210 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656148.00000-1256656208.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 6 triggers...
# Triggers::Clusterize: 4 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656206-1256656270
# 	- chunk 1256656206-1256656270 is loaded
#
# >>>>>>>>>> (06:45:52 UTC) [+5s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656206-1256656270 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656208.00000-1256656268.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 17 triggers...
# Triggers::Clusterize: 2 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656266-1256656330
# 	- chunk 1256656266-1256656330 is loaded
#
# >>>>>>>>>> (06:45:52 UTC) [+5s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656266-1256656330 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656268.00000-1256656328.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 1 triggers...
# Triggers::Clusterize: 1 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656326-1256656390
# 	- chunk 1256656326-1256656390 is loaded
#
# >>>>>>>>>> (06:45:53 UTC) [+6s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656326-1256656390 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656328.00000-1256656388.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 1 triggers...
# Triggers::Clusterize: 1 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656386-1256656450
# 	- chunk 1256656386-1256656450 is loaded
#
# >>>>>>>>>> (06:45:53 UTC) [+6s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656386-1256656450 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656388.00000-1256656448.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 1 triggers...
# Triggers::Clusterize: 1 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656446-1256656510
# 	- chunk 1256656446-1256656510 is loaded
#
# >>>>>>>>>> (06:45:54 UTC) [+7s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656446-1256656510 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656448.00000-1256656508.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 371 triggers...
# Triggers::Clusterize: 3 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656506-1256656570
# 	- chunk 1256656506-1256656570 is loaded
#
# >>>>>>>>>> (06:45:54 UTC) [+7s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656506-1256656570 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656508.00000-1256656568.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 4597 triggers...
# Triggers::Clusterize: 4 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656566-1256656630
# 	- chunk 1256656566-1256656630 is loaded
#
# >>>>>>>>>> (06:45:55 UTC) [+8s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656566-1256656630 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656568.00000-1256656628.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 2 triggers...
# Triggers::Clusterize: 2 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656626-1256656690
# 	- chunk 1256656626-1256656690 is loaded
#
# >>>>>>>>>> (06:45:55 UTC) [+8s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656626-1256656690 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656628.00000-1256656688.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 8 triggers...
# Triggers::Clusterize: 2 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656686-1256656750
# 	- chunk 1256656686-1256656750 is loaded
#
# >>>>>>>>>> (06:45:55 UTC) [+8s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656686-1256656750 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656688.00000-1256656748.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 97 triggers...
# Triggers::Clusterize: 3 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656746-1256656810
# 	- chunk 1256656746-1256656810 is loaded
#
# >>>>>>>>>> (06:45:56 UTC) [+9s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656746-1256656810 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656748.00000-1256656808.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 25 triggers...
# Triggers::Clusterize: 6 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656806-1256656870
# 	- chunk 1256656806-1256656870 is loaded
#
# >>>>>>>>>> (06:45:56 UTC) [+9s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656806-1256656870 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656808.00000-1256656868.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 130 triggers...
# Triggers::Clusterize: 3 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656866-1256656930
# 	- chunk 1256656866-1256656930 is loaded
#
# >>>>>>>>>> (06:45:57 UTC) [+10s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656866-1256656930 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656868.00000-1256656928.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 3 triggers...
# Triggers::Clusterize: 2 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656926-1256656990
# 	- chunk 1256656926-1256656990 is loaded
#
# >>>>>>>>>> (06:45:57 UTC) [+10s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656926-1256656990 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656928.00000-1256656988.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 6 triggers...
# Triggers::Clusterize: 2 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256656986-1256657050
# 	- chunk 1256656986-1256657050 is loaded
#
# >>>>>>>>>> (06:45:58 UTC) [+11s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256656986-1256657050 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256656988.00000-1256657048.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 72 triggers...
# Triggers::Clusterize: 1 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256657046-1256657110
# 	- chunk 1256657046-1256657110 is loaded
#
# >>>>>>>>>> (06:45:58 UTC) [+11s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657046-1256657110 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657048.00000-1256657108.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 2 triggers...
# Triggers::Clusterize: 2 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256657106-1256657170
# 	- chunk 1256657106-1256657170 is loaded
#
# >>>>>>>>>> (06:45:59 UTC) [+12s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657106-1256657170 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657108.00000-1256657168.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 0 triggers...
# Triggers::Clusterize: 0 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256657166-1256657230
# 	- chunk 1256657166-1256657230 is loaded
#
# >>>>>>>>>> (06:45:59 UTC) [+12s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657166-1256657230 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657168.00000-1256657228.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 2116 triggers...
# Triggers::Clusterize: 4 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256657226-1256657290
# 	- chunk 1256657226-1256657290 is loaded
#
# >>>>>>>>>> (06:46:00 UTC) [+13s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657226-1256657290 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657228.00000-1256657288.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 14 triggers...
# Triggers::Clusterize: 3 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256657286-1256657350
# 	- chunk 1256657286-1256657350 is loaded
#
# >>>>>>>>>> (06:46:00 UTC) [+13s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657286-1256657350 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657288.00000-1256657348.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 346 triggers...
# Triggers::Clusterize: 7 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256657346-1256657410
# 	- chunk 1256657346-1256657410 is loaded
#
# >>>>>>>>>> (06:46:00 UTC) [+13s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657346-1256657410 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657348.00000-1256657408.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 1616 triggers...
# Triggers::Clusterize: 16 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256657406-1256657470
# 	- chunk 1256657406-1256657470 is loaded
#
# >>>>>>>>>> (06:46:01 UTC) [+14s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657406-1256657470 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657408.00000-1256657468.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 659 triggers...
# Triggers::Clusterize: 9 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256657466-1256657530
# 	- chunk 1256657466-1256657530 is loaded
#
# >>>>>>>>>> (06:46:01 UTC) [+14s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657466-1256657530 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657468.00000-1256657528.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 7934 triggers...
# Triggers::Clusterize: 3 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256657526-1256657590
# 	- chunk 1256657526-1256657590 is loaded
#
# >>>>>>>>>> (06:46:02 UTC) [+15s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657526-1256657590 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657528.00000-1256657588.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 1459 triggers...
# Triggers::Clusterize: 8 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256657586-1256657650
# 	- chunk 1256657586-1256657650 is loaded
#
# >>>>>>>>>> (06:46:02 UTC) [+15s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657586-1256657650 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657588.00000-1256657648.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 56 triggers...
# Triggers::Clusterize: 6 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: 1256657646-1256657710
# 	- chunk 1256657646-1256657710 is loaded
#
# >>>>>>>>>> (06:46:03 UTC) [+16s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657646-1256657710 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657648.00000-1256657708.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 11 triggers...
# Triggers::Clusterize: 4 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# 	- chunk 1256657675-1256657739 is loaded
#
# >>>>>>>>>> (06:46:03 UTC) [+16s]: Processing L1:GWOSC-4KHZ_R1_STRAIN 1256657675-1256657739 <<<<<<<<<<
#
# Omicron::LoadData: load data vector...
# Omicron::Condition: condition data vector...
# Sample::Transform: remove DC component...
# Sample::Transform: resample input data...
# Sample::Resample: apply anti-aliasing filters
# Sample::Resample: decimate time-series
# Spectrum::AddData: compute PSD
# Spectrum::AddData: compute PSD
# Omicron::Project: project data onto the tiles...
# Otile::ProjectData: project the data on the Q planes
# Omicron::WriteOutput: write chunk output...
# Otile::SaveTriggers: saving triggers for L1:GWOSC-4KHZ_R1_STRAIN in 1256657708.00000-1256657737.00000
# Triggers::SortTriggers: sorting triggers
# Triggers::Clusterize: cluster 6 triggers...
# Triggers::Clusterize: 2 clusters were found
# MakeTriggers::Reset: reset all
# Omicron::NewChunk: call a new chunk...
# Osequence::NewChunk: end of segments
# Omicron::NewChannel: load a new channel...
# 	- no more channels to load
#
# >>>>>>>>>> (06:46:04 UTC) [+17s]: Omicron processing is over <<<<<<<<<<
#
#
# ************* Omicron status info *************
# requested start         = 1256655666
# requested end           = 1256657739
# requested livetime      = 2073 s
# number of chunks        = 35
#
# *** L1:GWOSC-4KHZ_R1_STRAIN
# number of data calls         = 35
# number of conditioning calls = 35
# number of projection calls   = 35
# number of write calls        = 35
# start_out                    = 1256655668
# end_out                      = 1256657737
# trigger livetime             = 2069s (99.80704%)
# ***********************************************
#
# ffl::Reset: reset ffl
# 0

# %% [markdown]
# ### Gathering triggers

# %%
h5s = glob.glob(f"{output_dir}/{channel}/*.h5")
h5s = sorted(h5s)
triggers = []
for h5 in h5s:
    with h5py.File(h5, 'r') as f:
        # Look up for the keys
        # print(f.keys())
        triggers.extend(f['triggers'][:])

print(f"Number of the triggers from {start} to {end}: {len(triggers)}")
# Gather trigger times
trigger_times = [float(trigger['time']) for trigger in triggers]
# Gather trigger frequencies
trigger_frequencies = [float(trigger['frequency']) for trigger in triggers]
# Gather trigger snrs
trigger_snrs = [float(trigger['snr']) for trigger in triggers]
# Out:
# Number of the triggers from 1256655666 to 1256657739: 124

# %% [markdown]
# ### Whiten Time Series Data

# %%
# Reading time series data
ts = TimeSeries.read(
    source=gwf_file,
    channel=channel,
    start=start,
    end=end,
)
ts[:10*sample_rate].plot(title='Raw Strain').show()

# Calculating ASD
fftlength = 32
overlap = fftlength/2
asd = ts.asd(
    fftlength=fftlength,
    overlap=overlap,
    method='median',
)

# Whiten time series data
wh_ts = ts.whiten(asd=asd)
wh_ts[:10*sample_rate].plot(title='Whitened Strain').show()
# Out:
# <Plot size 1200x400 with 1 Axes>
# <Plot size 1200x400 with 1 Axes>

# %% [markdown]
# ### Get Spectrogram

# %%
# Crop the time series first and then calculate the spectrogram
id = 21
trigger_time = trigger_times[id]
trigger_frequency = trigger_frequencies[id]
trigger_snr = trigger_snrs[id]
print(f"Time: {trigger_time}, Frequency: {trigger_frequency}, SNR: {trigger_snr}")

# Crop time series data
duration = 2
crop_head, crop_tail = 1, 1
t0 = trigger_time - (duration/2 + crop_head)
crop_ts = wh_ts.crop(t0, t0+duration+crop_head+crop_tail)
crop_ts.plot(title=f"Trigger: {trigger_time} s").show()

# Q-transform
qspec_short = crop_ts.q_transform(
    qrange=(50,50),
    frange=(5, 1500),
    tres=1/200,
    # logf=True,
    # fres=200,
    logf=False,
    fres=0.5,
    whiten=False,
)
qspec_view = qspec_short.crop(trigger_time-duration/2, trigger_time+duration/2)
amplitude = qspec_view.T.to_value()
times = qspec_view.times.to_value()
frequencies = qspec_view.frequencies.to_value()
plt.figure(figsize=[16,6])
plt.title(f"Spectrogram of Trigger, Time:{trigger_time:.3f} s, Frequency:{trigger_frequency:.3f} Hz, SNR:{trigger_snr:.3f}")
plt.pcolormesh(
    times,
    frequencies,
    amplitude,
    # vmax=20,
    cmap='cividis',
)
plt.xlabel("Time [s]")
plt.ylabel("Frequency [Hz]")
plt.yscale('log')
plt.ylim([5, 1500])
plt.colorbar(cmap='cividis')
plt.show()
# Out:
# Time: 1256656115.644531, Frequency: 42.33227450091618, SNR: 30.338991355505236
# <Plot size 1200x400 with 1 Axes>

# %%
print(type(qspec_short))
print(qspec_short)
print(qspec_short.value.shape)
qspec_short.name = "L1-test"
qspec_short.channel = "L1-test"
qspec_short.write("/home/jerry/GW/glitch-classification/Data/qspec-test.hdf5", format='hdf5')
# Out:
# <class 'gwpy.spectrogram.spectrogram.Spectrogram'>
# Spectrogram([[ 1.        ,  1.111     ,  0.37447447, ...,
#                1.0061698 ,  1.0061698 ,  1.0061698 ],
#              [ 1.        ,  1.112433  ,  0.36731973, ...,
#                0.04901422,  0.04901422,  0.04901422],
#              [ 1.        ,  1.1138538 ,  0.3602426 , ...,
#                1.4573817 ,  1.4573817 ,  1.4573817 ],
#              ...,
#              [ 1.        ,  1.2603475 , -0.36850142, ...,
#                0.26812854,  0.26812854,  0.26812854],
#              [ 1.        ,  1.2651174 , -0.39594647, ...,
#                0.54266405,  0.54266405,  0.54266405],
#              [ 1.        ,  1.269886  , -0.42340282, ...,
#                1.6230283 ,  1.6230283 ,  1.6230283 ]]
#             unit: dimensionless,
#             name: L1-test,
#             epoch: 1256655691.8757324,
#             channel: L1-test,
#             x0: 1256655691.8757324 s,
#             dx: 0.005 s,
#             xindex: [1.25665569e+09 1.25665569e+09 1.25665569e+09 ... 1.25665569e+09
#                      1.25665569e+09 1.25665569e+09] s,
#             y0: 5.0 Hz,
#             dy: 0.5 Hz,
#             yindex: [   5.     5.5    6.  ... 1498.5 1499.  1499.5] Hz)
# (600, 2990)
# <Closed HDF5 dataset>

# %%
with h5py.File("/home/jerry/GW/glitch-classification/Data/qspec-test.hdf5", 'r') as f:
    print(f.keys())
    print(f['L1-test'].attrs.keys())
    print(f['L1-test'].attrs['dx'])
# Out:
# <KeysViewHDF5 ['L1-test']>
# <KeysViewHDF5 ['channel', 'dx', 'dy', 'name', 'unit', 'x0', 'xunit', 'y0', 'yunit']>
# 0.005

# %%
import numpy as np
data = np.array([1,2,3,4,5])
with h5py.File("./test.hdf5", 'w') as f:
    dset = f.create_dataset(
        "test",
        dtype=data.dtype,
        data=data,
    )
    dset.attrs['title'] = "Hello"
    dset.attrs['ranking'] = 4

# %%
with h5py.File("./test.hdf5", 'r') as f:
    print(f['test'])
    print(f['test'].attrs['title'])
    print(f['test'].attrs['ranking'])
# Out:
# <HDF5 dataset "test": shape (5,), type "<i8">
# Hello
# 4

# %%
# Calculate spectrogram of the whole whitened time series data
qspec = wh_ts.q_transform(
    qrange=(50,50),
    frange=(5, 1500),
    tres=1/200,
    fres=200,
    logf=True,
    whiten=False,
)

# %%
# Choosing triggers and plot the spectrogram
id = 20
trigger_time = trigger_times[id]
trigger_frequency = trigger_frequencies[id]
trigger_snr = trigger_snrs[id]
print(f"Time: {trigger_time}, Frequency: {trigger_frequency}, SNR: {trigger_snr}")

duration = 2
t0 = trigger_time - duration/2

qspec_view = qspec.crop(t0, t0+duration)
amplitude = qspec_view.T.to_value()
times = qspec_view.times.to_value()
frequencies = qspec_view.frequencies.to_value()
plt.figure(figsize=[16,6])
plt.title(f"Spectrogram of Trigger, Time:{trigger_time:.3f} s, Frequency:{trigger_frequency:.3f} Hz, SNR:{trigger_snr:.3f}")
plt.pcolormesh(
    times,
    frequencies,
    amplitude,
    # vmax=20,
    cmap='cividis',
)
plt.xlabel("Time [s]")
plt.ylabel("Frequency [Hz]")
plt.yscale('log')
plt.colorbar(cmap='cividis')
plt.show()
# Out:
# Time: 1256656108.255859, Frequency: 89.27487917327174, SNR: 7.061805892207992

# %%
print(trigger_snrs)
for i, snr in enumerate(trigger_snrs):
    if snr >= 100:
        print(i, snr)
# Out:
# [5.032229604127074, 44.40856106795152, 5.667487115351235, 8.80533455939033, 5.064844053021606, 9.162215900413171, 5.100228550345878, 9.117858446062034, 6.583309332701542, 6.337798281880494, 10.6039293440067, 104.147084391904, 10.319432777165126, 5.023766275198698, 5.358843429681596, 5.18188731955069, 5.045738558989289, 5.191920682069558, 5.132395045364208, 315.785014125254, 7.061805892207992, 30.338991355505236, 5.4202499056119935, 5.195136813471443, 5.230469272226459, 5.261548759377985, 5.044314196720507, 5.794337544053471, 5.60817108014871, 5.062899698318892, 5.0075053056701515, 5.025435127787002, 6.71068784184045, 5.111267727532588, 16.559937797007034, 5.125172612432482, 8.20980984360255, 64.63358404504501, 117.05658400737626, 5.0764735320290075, 5.065398636540723, 5.391072212065601, 5.063648747526636, 11.472420253652482, 5.303867776206812, 5.368959565104804, 5.311264412007554, 5.242519101905582, 5.200066435067701, 5.969666208652118, 5.010686146566114, 5.270293239208071, 5.062264919373539, 12.083190159479118, 5.648183925211107, 5.021753676090643, 5.1422139414248775, 5.5702388329747645, 5.1349860947477834, 9.51609657768716, 5.053765346178636, 5.0463240904080635, 10.15943793849533, 85.55789444004073, 5.535494573665767, 13.284546694487393, 6.139475934117681, 5.338224861875948, 5.151853768800193, 5.711859380824276, 12.089431032549976, 5.128260087913375, 6.300171758877651, 8.366279428844999, 6.689888560548954, 5.193085896216665, 5.001981932307278, 5.8386589837127785, 11.337773722928873, 6.212849157200196, 9.181909739624286, 5.697905707681165, 5.2424410247577775, 16.68448175225794, 10.720798579561208, 13.900748813043876, 5.417731326104342, 6.107419678553882, 5.78908338406299, 11.089601718920942, 9.36279839768974, 10.874901950166233, 6.07980731457308, 5.011730993968276, 13.992376413804735, 5.713966256209019, 9.520943757692688, 12.091411887684856, 7.266635466946223, 5.439362900837547, 6.004582005875174, 5.06398078761626, 240.26868503109714, 8.347332367075492, 14.700211249540486, 5.667024883528759, 5.892604888899862, 5.243900097200163, 5.860605790429078, 6.7768297672302085, 19.35627733452391, 7.571188668318248, 7.588789668333575, 5.130556446039444, 5.134550550364782, 7.0837685872506855, 5.315837233138742, 5.464717905437757, 5.253662977795401, 5.117647883121489, 5.581318714710901, 5.060328866755551, 5.062763141672441, 5.601387093861846]
# 11 104.147084391904
# 19 315.785014125254
# 38 117.05658400737626
# 102 240.26868503109714
